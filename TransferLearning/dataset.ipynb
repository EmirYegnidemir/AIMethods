# %%
# !pip install bing-image-downloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !mkdir goldeneagles

# %%
from bing_image_downloader import downloader
downloader.download("humming bird", limit = 100, output_dir='goldeneagles')
# Out:
# [%] Downloading Images to /content/goldeneagles/humming bird
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://images.fineartamerica.com/images/artworkimages/mediumlarge/2/colorful-humming-bird-image-by-david-g-hemmings.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://wallpapercave.com/wp/nhiZUpI.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://images.pexels.com/photos/731706/pexels-photo-731706.jpeg?cs=srgb&amp;dl=shallow-focus-photography-of-green-humming-bird-731706.jpg&amp;fm=jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://pavbca.com/walldb/original/1/b/a/462808.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.cayaya-birding.com/species/White-eared-Hummingbird_9.jpg
# [%] File Downloaded !
#
# ...

# %%
# !mkdir pigeons
downloader.download("pigeon", limit = 100, output_dir='pigeons')
# Out:
# [%] Downloading Images to /content/pigeons/pigeon
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.meigspointnaturecenter.org/wp-content/uploads/2020/08/common-pigeon-ss-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.folomojo.com/wp-content/uploads/2015/05/29/iStock_000015691482_Double.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://2.bp.blogspot.com/-BnymSMvfDJ0/UoyRuu67GkI/AAAAAAAAJlw/rz92fMb6q8I/s1600/Pigeon+Bird+New+Wallpaper+07.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://cdn.phys.org/newman/gfx/news/hires/2015/pigeon.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.publicdomainpictures.net/pictures/40000/velka/pigeon-1364561001yVr.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://s.hdnux.com/photos/37/03/22/8139964/3/1200x0.jpg
# [%] File Downloaded !
#
# ...

# %%
# !zip -r goldeneagles.zip goldeneagles/
# Out:
#   adding: goldeneagles/ (stored 0%)
#   adding: goldeneagles/humming bird/ (stored 0%)
#   adding: goldeneagles/humming bird/Image_81.jpg (deflated 1%)
#   adding: goldeneagles/humming bird/Image_27.jpg (deflated 4%)
#   adding: goldeneagles/humming bird/Image_29.jpg (deflated 1%)
#   adding: goldeneagles/humming bird/Image_24.jpg (deflated 4%)
#   adding: goldeneagles/humming bird/Image_40.jpg (deflated 0%)
#   adding: goldeneagles/humming bird/Image_34.jpg (deflated 0%)
#   adding: goldeneagles/humming bird/Image_80.jpg (deflated 1%)
#   adding: goldeneagles/humming bird/Image_58.jpg (deflated 1%)
#   adding: goldeneagles/humming bird/Image_71.jpg (deflated 0%)
#   adding: goldeneagles/humming bird/Image_88.jpg (deflated 7%)
#   adding: goldeneagles/humming bird/Image_3.jpeg (deflated 0%)
#   adding: goldeneagles/humming bird/Image_65.jpg (deflated 1%)
#   adding: goldeneagles/humming bird/Image_30.jpg (deflated 1%)
#   adding: goldeneagles/humming bird/Image_94.jpg (deflated 0%)
# ...

# %%
# !zip -r pigeons.zip pigeons/
# Out:
#   adding: pigeons/ (stored 0%)
#   adding: pigeons/pigeon/ (stored 0%)
#   adding: pigeons/pigeon/Image_82.jpg (deflated 1%)
#   adding: pigeons/pigeon/Image_81.jpg (deflated 2%)
#   adding: pigeons/pigeon/Image_27.jpg (deflated 8%)
#   adding: pigeons/pigeon/Image_29.jpg (deflated 0%)
#   adding: pigeons/pigeon/Image_24.jpg (deflated 1%)
#   adding: pigeons/pigeon/Image_54.JPG (deflated 0%)
#   adding: pigeons/pigeon/Image_40.jpg (deflated 14%)
#   adding: pigeons/pigeon/Image_77.JPG (deflated 0%)
#   adding: pigeons/pigeon/Image_80.jpg (deflated 4%)
#   adding: pigeons/pigeon/Image_58.jpg (deflated 2%)
#   adding: pigeons/pigeon/Image_71.jpg (deflated 0%)
#   adding: pigeons/pigeon/Image_88.jpg (deflated 0%)
#   adding: pigeons/pigeon/Image_33.JPG (deflated 1%)
#   adding: pigeons/pigeon/Image_65.jpg (deflated 0%)
#   adding: pigeons/pigeon/Image_30.jpg (deflated 0%)
#   adding: pigeons/pigeon/Image_94.jpg (deflated 13%)
#   adding: pigeons/pigeon/Image_13.jpg (deflated 1%)
# ...
